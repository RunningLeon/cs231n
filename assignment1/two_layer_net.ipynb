# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027204961e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 0.0189654196061

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 3.440708e-09
# b2 max relative error: 3.865091e-11
# W1 max relative error: 3.561318e-09
# b1 max relative error: 1.555470e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171436435329

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302762
# iteration 100 / 1000: loss 2.302358
# iteration 200 / 1000: loss 2.297404
# iteration 300 / 1000: loss 2.258897
# iteration 400 / 1000: loss 2.202975
# iteration 500 / 1000: loss 2.116816
# iteration 600 / 1000: loss 2.049789
# iteration 700 / 1000: loss 1.985711
# iteration 800 / 1000: loss 2.003726
# iteration 900 / 1000: loss 1.948076
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 
best_val = -1

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
result = {}
hidden_size_list = np.arange(20, 100, 20)
batch_size_list = np.arange(100, 500, 100)
learning_rate_list = np.linspace(1e-4, 0.1, 20)
learning_rate_decay_list = np.linspace(0.5, 0.99, 10)
reg_list = np.linspace(0.01, 0.99, 10)
i = 0
for hds in hidden_size_list:
    for bs in batch_size_list:
        for lr in learning_rate_list:
            for lrd in learning_rate_decay_list:
                for reg in reg_list:
                    net = TwoLayerNet(input_size, hds, num_classes)
                    stats = net.train(X_train, y_train, X_val, y_val, num_iters=2000, batch_size=bs,learning_rate=lr, learning_rate_decay=lrd,
                        reg=reg, verbose=False)
                    val_acc = (net.predict(X_val) == y_val).mean()
                    if val_acc > best_val:
                        best_val = val_acc
                        best_net = net
                    result[(hds, bs, lr, lrd, reg)] = (stats, val_acc)
                    i += 1
                    print('Finish {} (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = ({},{},{},{},{}),the validation accuracy:{} '.format(i, hds, bs, lr, lrd, reg, val_acc))



#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# Finish 1 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5,0.01),the validation accuracy:0.201
# Finish 2 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5,0.11888888888888888),the validation accuracy:0.209
# Finish 3 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5,0.22777777777777777),the validation accuracy:0.202
# Finish 4 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5,0.33666666666666667),the validation accuracy:0.203
# Finish 5 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5,0.44555555555555554),the validation accuracy:0.191
# Finish 6 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5,0.5544444444444444),the validation accuracy:0.217
# Finish 7 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5,0.6633333333333333),the validation accuracy:0.207
# Finish 8 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5,0.7722222222222221),the validation accuracy:0.185
# Finish 9 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5,0.8811111111111111),the validation accuracy:0.206
# Finish 10 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5,0.99),the validation accuracy:0.212
# Finish 11 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5544444444444444,0.01),the validation accuracy:0.233
# Finish 12 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5544444444444444,0.11888888888888888),the validation accuracy:0.239
# Finish 13 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5544444444444444,0.22777777777777777),the validation accuracy:0.225
# Finish 14 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5544444444444444,0.33666666666666667),the validation accuracy:0.235
# Finish 15 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5544444444444444,0.44555555555555554),the validation accuracy:0.232
# Finish 16 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5544444444444444,0.5544444444444444),the validation accuracy:0.232
# Finish 17 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5544444444444444,0.6633333333333333),the validation accuracy:0.239
# Finish 18 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5544444444444444,0.7722222222222221),the validation accuracy:0.24
# Finish 19 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5544444444444444,0.8811111111111111),the validation accuracy:0.223
# Finish 20 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.5544444444444444,0.99),the validation accuracy:0.235
# Finish 21 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6088888888888889,0.01),the validation accuracy:0.246
# Finish 22 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6088888888888889,0.11888888888888888),the validation accuracy:0.226
# Finish 23 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6088888888888889,0.22777777777777777),the validation accuracy:0.258
# Finish 24 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6088888888888889,0.33666666666666667),the validation accuracy:0.241
# Finish 25 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6088888888888889,0.44555555555555554),the validation accuracy:0.242
# Finish 26 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6088888888888889,0.5544444444444444),the validation accuracy:0.246
# Finish 27 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6088888888888889,0.6633333333333333),the validation accuracy:0.246
# Finish 28 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6088888888888889,0.7722222222222221),the validation accuracy:0.241
# Finish 29 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6088888888888889,0.8811111111111111),the validation accuracy:0.244
# Finish 30 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6088888888888889,0.99),the validation accuracy:0.25
# Finish 31 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6633333333333333,0.01),the validation accuracy:0.271
# Finish 32 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6633333333333333,0.11888888888888888),the validation accuracy:0.256
# Finish 33 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6633333333333333,0.22777777777777777),the validation accuracy:0.26
# Finish 34 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6633333333333333,0.33666666666666667),the validation accuracy:0.273
# Finish 35 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6633333333333333,0.44555555555555554),the validation accuracy:0.26
# Finish 36 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6633333333333333,0.5544444444444444),the validation accuracy:0.252
# Finish 37 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6633333333333333,0.6633333333333333),the validation accuracy:0.267
# Finish 38 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6633333333333333,0.7722222222222221),the validation accuracy:0.249
# Finish 39 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6633333333333333,0.8811111111111111),the validation accuracy:0.265
# Finish 40 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.6633333333333333,0.99),the validation accuracy:0.266
# Finish 41 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7177777777777777,0.01),the validation accuracy:0.275
# Finish 42 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7177777777777777,0.11888888888888888),the validation accuracy:0.274
# Finish 43 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7177777777777777,0.22777777777777777),the validation accuracy:0.286
# Finish 44 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7177777777777777,0.33666666666666667),the validation accuracy:0.268
# Finish 45 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7177777777777777,0.44555555555555554),the validation accuracy:0.272
# Finish 46 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7177777777777777,0.5544444444444444),the validation accuracy:0.281
# Finish 47 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7177777777777777,0.6633333333333333),the validation accuracy:0.283
# Finish 48 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7177777777777777,0.7722222222222221),the validation accuracy:0.281
# Finish 49 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7177777777777777,0.8811111111111111),the validation accuracy:0.275
# Finish 50 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7177777777777777,0.99),the validation accuracy:0.28
# Finish 51 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7722222222222221,0.01),the validation accuracy:0.294
# Finish 52 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7722222222222221,0.11888888888888888),the validation accuracy:0.304
# Finish 53 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7722222222222221,0.22777777777777777),the validation accuracy:0.294
# Finish 54 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7722222222222221,0.33666666666666667),the validation accuracy:0.296
# Finish 55 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7722222222222221,0.44555555555555554),the validation accuracy:0.288
# Finish 56 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7722222222222221,0.5544444444444444),the validation accuracy:0.294
# Finish 57 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7722222222222221,0.6633333333333333),the validation accuracy:0.298
# Finish 58 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7722222222222221,0.7722222222222221),the validation accuracy:0.284
# Finish 59 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7722222222222221,0.8811111111111111),the validation accuracy:0.308
# Finish 60 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.7722222222222221,0.99),the validation accuracy:0.293
# Finish 61 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8266666666666667,0.01),the validation accuracy:0.329
# Finish 62 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8266666666666667,0.11888888888888888),the validation accuracy:0.325
# Finish 63 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8266666666666667,0.22777777777777777),the validation accuracy:0.319
# Finish 64 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8266666666666667,0.33666666666666667),the validation accuracy:0.32
# Finish 65 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8266666666666667,0.44555555555555554),the validation accuracy:0.32
# Finish 66 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8266666666666667,0.5544444444444444),the validation accuracy:0.312
# Finish 67 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8266666666666667,0.6633333333333333),the validation accuracy:0.327
# Finish 68 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8266666666666667,0.7722222222222221),the validation accuracy:0.322
# Finish 69 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8266666666666667,0.8811111111111111),the validation accuracy:0.337
# Finish 70 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8266666666666667,0.99),the validation accuracy:0.316
# Finish 71 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8811111111111111,0.01),the validation accuracy:0.34
# Finish 72 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8811111111111111,0.11888888888888888),the validation accuracy:0.348
# Finish 73 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8811111111111111,0.22777777777777777),the validation accuracy:0.331
# Finish 74 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8811111111111111,0.33666666666666667),the validation accuracy:0.342
# Finish 75 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8811111111111111,0.44555555555555554),the validation accuracy:0.326
# Finish 76 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8811111111111111,0.5544444444444444),the validation accuracy:0.329
# Finish 77 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8811111111111111,0.6633333333333333),the validation accuracy:0.335
# Finish 78 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8811111111111111,0.7722222222222221),the validation accuracy:0.344
# Finish 79 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8811111111111111,0.8811111111111111),the validation accuracy:0.332
# Finish 80 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.8811111111111111,0.99),the validation accuracy:0.325
# Finish 81 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.9355555555555555,0.01),the validation accuracy:0.351
# Finish 82 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.9355555555555555,0.11888888888888888),the validation accuracy:0.343
# Finish 83 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.9355555555555555,0.22777777777777777),the validation accuracy:0.342
# Finish 84 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.9355555555555555,0.33666666666666667),the validation accuracy:0.361
# Finish 85 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.9355555555555555,0.44555555555555554),the validation accuracy:0.355
# Finish 86 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.9355555555555555,0.5544444444444444),the validation accuracy:0.345
# Finish 87 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.9355555555555555,0.6633333333333333),the validation accuracy:0.357
# Finish 88 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.9355555555555555,0.7722222222222221),the validation accuracy:0.357
# Finish 89 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.9355555555555555,0.8811111111111111),the validation accuracy:0.346
# Finish 90 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.9355555555555555,0.99),the validation accuracy:0.358
# Finish 91 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.99,0.01),the validation accuracy:0.375
# Finish 92 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.99,0.11888888888888888),the validation accuracy:0.378
# Finish 93 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.99,0.22777777777777777),the validation accuracy:0.371
# Finish 94 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.99,0.33666666666666667),the validation accuracy:0.36
# Finish 95 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.99,0.44555555555555554),the validation accuracy:0.376
# Finish 96 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.99,0.5544444444444444),the validation accuracy:0.367
# Finish 97 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.99,0.6633333333333333),the validation accuracy:0.363
# Finish 98 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.99,0.7722222222222221),the validation accuracy:0.367
# Finish 99 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.99,0.8811111111111111),the validation accuracy:0.357
# Finish 100 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.0001,0.99,0.99),the validation accuracy:0.362
# Finish 101 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5,0.01),the validation accuracy:0.464
# Finish 102 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5,0.11888888888888888),the validation accuracy:0.454
# Finish 103 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5,0.22777777777777777),the validation accuracy:0.467
# Finish 104 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5,0.33666666666666667),the validation accuracy:0.446
# Finish 105 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5,0.44555555555555554),the validation accuracy:0.481
# Finish 106 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5,0.5544444444444444),the validation accuracy:0.482
# Finish 107 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5,0.6633333333333333),the validation accuracy:0.466
# Finish 108 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5,0.7722222222222221),the validation accuracy:0.465
# Finish 109 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5,0.8811111111111111),the validation accuracy:0.472
# Finish 110 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5,0.99),the validation accuracy:0.467
# Finish 111 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5544444444444444,0.01),the validation accuracy:0.457
# Finish 112 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5544444444444444,0.11888888888888888),the validation accuracy:0.463
# Finish 113 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5544444444444444,0.22777777777777777),the validation accuracy:0.449
# Finish 114 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5544444444444444,0.33666666666666667),the validation accuracy:0.471
# Finish 115 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5544444444444444,0.44555555555555554),the validation accuracy:0.459
# Finish 116 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5544444444444444,0.5544444444444444),the validation accuracy:0.465
# Finish 117 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5544444444444444,0.6633333333333333),the validation accuracy:0.472
# Finish 118 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5544444444444444,0.7722222222222221),the validation accuracy:0.472
# Finish 119 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5544444444444444,0.8811111111111111),the validation accuracy:0.458
# Finish 120 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.5544444444444444,0.99),the validation accuracy:0.467
# Finish 121 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6088888888888889,0.01),the validation accuracy:0.448
# Finish 122 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6088888888888889,0.11888888888888888),the validation accuracy:0.461
# Finish 123 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6088888888888889,0.22777777777777777),the validation accuracy:0.464
# Finish 124 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6088888888888889,0.33666666666666667),the validation accuracy:0.455
# Finish 125 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6088888888888889,0.44555555555555554),the validation accuracy:0.475
# Finish 126 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6088888888888889,0.5544444444444444),the validation accuracy:0.459
# Finish 127 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6088888888888889,0.6633333333333333),the validation accuracy:0.472
# Finish 128 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6088888888888889,0.7722222222222221),the validation accuracy:0.446
# Finish 129 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6088888888888889,0.8811111111111111),the validation accuracy:0.451
# Finish 130 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6088888888888889,0.99),the validation accuracy:0.454
# D:\Leon-Ma\000-Personal\cs231n\assignment1\cs231n\classifiers\neural_net.py:101: RuntimeWarning: divide by zero encountered in log
#   loss = - np.sum(np.log(softmax_output[range(N), list(y)]))
# Finish 131 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6633333333333333,0.01),the validation accuracy:0.257
# Finish 132 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6633333333333333,0.11888888888888888),the validation accuracy:0.224
# Finish 133 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6633333333333333,0.22777777777777777),the validation accuracy:0.218
# Finish 134 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6633333333333333,0.33666666666666667),the validation accuracy:0.235
# Finish 135 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6633333333333333,0.44555555555555554),the validation accuracy:0.217
# Finish 136 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6633333333333333,0.5544444444444444),the validation accuracy:0.466
# Finish 137 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6633333333333333,0.6633333333333333),the validation accuracy:0.442
# Finish 138 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6633333333333333,0.7722222222222221),the validation accuracy:0.453
# Finish 139 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6633333333333333,0.8811111111111111),the validation accuracy:0.226
# Finish 140 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.6633333333333333,0.99),the validation accuracy:0.222
# Finish 141 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7177777777777777,0.01),the validation accuracy:0.188
# Finish 142 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7177777777777777,0.11888888888888888),the validation accuracy:0.175
# Finish 143 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7177777777777777,0.22777777777777777),the validation accuracy:0.245
# Finish 144 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7177777777777777,0.33666666666666667),the validation accuracy:0.143
# Finish 145 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7177777777777777,0.44555555555555554),the validation accuracy:0.173
# Finish 146 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7177777777777777,0.5544444444444444),the validation accuracy:0.225
# Finish 147 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7177777777777777,0.6633333333333333),the validation accuracy:0.218
# Finish 148 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7177777777777777,0.7722222222222221),the validation accuracy:0.171
# Finish 149 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7177777777777777,0.8811111111111111),the validation accuracy:0.223
# Finish 150 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7177777777777777,0.99),the validation accuracy:0.233
# Finish 151 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7722222222222221,0.01),the validation accuracy:0.165
# Finish 152 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7722222222222221,0.11888888888888888),the validation accuracy:0.157
# Finish 153 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7722222222222221,0.22777777777777777),the validation accuracy:0.167
# Finish 154 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7722222222222221,0.33666666666666667),the validation accuracy:0.171
# Finish 155 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7722222222222221,0.44555555555555554),the validation accuracy:0.24
# Finish 156 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7722222222222221,0.5544444444444444),the validation accuracy:0.177
# Finish 157 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7722222222222221,0.6633333333333333),the validation accuracy:0.155
# Finish 158 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7722222222222221,0.7722222222222221),the validation accuracy:0.169
# Finish 159 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7722222222222221,0.8811111111111111),the validation accuracy:0.179
# Finish 160 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.7722222222222221,0.99),the validation accuracy:0.212
# D:\Leon-Ma\000-Personal\cs231n\assignment1\cs231n\classifiers\neural_net.py:99: RuntimeWarning: overflow encountered in subtract
#   scores = scores - np.max(scores, axis = 1).reshape(-1, 1)
# D:\Leon-Ma\000-Personal\cs231n\assignment1\cs231n\classifiers\neural_net.py:99: RuntimeWarning: invalid value encountered in subtract
#   scores = scores - np.max(scores, axis = 1).reshape(-1, 1)
# D:\Leon-Ma\000-Personal\cs231n\assignment1\cs231n\classifiers\neural_net.py:80: RuntimeWarning: invalid value encountered in maximum
#   h_output = np.maximum(0, X.dot(W1) + b1)
# D:\Leon-Ma\000-Personal\cs231n\assignment1\cs231n\classifiers\neural_net.py:123: RuntimeWarning: invalid value encountered in greater
#   dh_relu = (h_output > 0) *dh
# D:\Leon-Ma\000-Personal\cs231n\assignment1\cs231n\classifiers\neural_net.py:235: RuntimeWarning: invalid value encountered in maximum
#   h = np.maximum(0, X.dot(self.params['W1']) + self.params['b1'])
# Finish 161 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8266666666666667,0.01),the validation accuracy:0.087
# Finish 162 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8266666666666667,0.11888888888888888),the validation accuracy:0.192
# Finish 163 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8266666666666667,0.22777777777777777),the validation accuracy:0.169
# Finish 164 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8266666666666667,0.33666666666666667),the validation accuracy:0.087
# Finish 165 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8266666666666667,0.44555555555555554),the validation accuracy:0.087
# Finish 166 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8266666666666667,0.5544444444444444),the validation accuracy:0.087
# Finish 167 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8266666666666667,0.6633333333333333),the validation accuracy:0.087
# Finish 168 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8266666666666667,0.7722222222222221),the validation accuracy:0.087
# Finish 169 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8266666666666667,0.8811111111111111),the validation accuracy:0.148
# Finish 170 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8266666666666667,0.99),the validation accuracy:0.185
# Finish 171 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8811111111111111,0.01),the validation accuracy:0.087
# Finish 172 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8811111111111111,0.11888888888888888),the validation accuracy:0.087
# Finish 173 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8811111111111111,0.22777777777777777),the validation accuracy:0.087
# Finish 174 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8811111111111111,0.33666666666666667),the validation accuracy:0.087
# Finish 175 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8811111111111111,0.44555555555555554),the validation accuracy:0.087
# Finish 176 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8811111111111111,0.5544444444444444),the validation accuracy:0.087
# Finish 177 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8811111111111111,0.6633333333333333),the validation accuracy:0.087
# Finish 178 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8811111111111111,0.7722222222222221),the validation accuracy:0.087
# Finish 179 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8811111111111111,0.8811111111111111),the validation accuracy:0.087
# Finish 180 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.8811111111111111,0.99),the validation accuracy:0.087
# Finish 181 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.9355555555555555,0.01),the validation accuracy:0.087
# Finish 182 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.9355555555555555,0.11888888888888888),the validation accuracy:0.087
# Finish 183 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.9355555555555555,0.22777777777777777),the validation accuracy:0.087
# Finish 184 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.9355555555555555,0.33666666666666667),the validation accuracy:0.087
# Finish 185 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.9355555555555555,0.44555555555555554),the validation accuracy:0.087
# Finish 186 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.9355555555555555,0.5544444444444444),the validation accuracy:0.087
# Finish 187 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.9355555555555555,0.6633333333333333),the validation accuracy:0.087
# Finish 188 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.9355555555555555,0.7722222222222221),the validation accuracy:0.087
# Finish 189 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.9355555555555555,0.8811111111111111),the validation accuracy:0.087
# Finish 190 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.9355555555555555,0.99),the validation accuracy:0.087
# Finish 191 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.99,0.01),the validation accuracy:0.087
# Finish 192 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.99,0.11888888888888888),the validation accuracy:0.087
# Finish 193 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.99,0.22777777777777777),the validation accuracy:0.087
# Finish 194 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.99,0.33666666666666667),the validation accuracy:0.087
# Finish 195 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.99,0.44555555555555554),the validation accuracy:0.087
# Finish 196 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.99,0.5544444444444444),the validation accuracy:0.087
# Finish 197 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.99,0.6633333333333333),the validation accuracy:0.087
# Finish 198 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.99,0.7722222222222221),the validation accuracy:0.087
# Finish 199 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.99,0.8811111111111111),the validation accuracy:0.087
# Finish 200 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.005357894736842106,0.99,0.99),the validation accuracy:0.087
# Finish 201 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5,0.01),the validation accuracy:0.237
# Finish 202 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5,0.11888888888888888),the validation accuracy:0.234
# Finish 203 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5,0.22777777777777777),the validation accuracy:0.171
# Finish 204 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5,0.33666666666666667),the validation accuracy:0.318
# Finish 205 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5,0.44555555555555554),the validation accuracy:0.235
# Finish 206 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5,0.5544444444444444),the validation accuracy:0.249
# Finish 207 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5,0.6633333333333333),the validation accuracy:0.15
# Finish 208 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5,0.7722222222222221),the validation accuracy:0.261
# Finish 209 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5,0.8811111111111111),the validation accuracy:0.261
# Finish 210 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5,0.99),the validation accuracy:0.258
# Finish 211 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5544444444444444,0.01),the validation accuracy:0.087
# Finish 212 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5544444444444444,0.11888888888888888),the validation accuracy:0.087
# Finish 213 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5544444444444444,0.22777777777777777),the validation accuracy:0.087
# Finish 214 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5544444444444444,0.33666666666666667),the validation accuracy:0.087
# Finish 215 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5544444444444444,0.44555555555555554),the validation accuracy:0.087
# Finish 216 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5544444444444444,0.5544444444444444),the validation accuracy:0.087
# Finish 217 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5544444444444444,0.6633333333333333),the validation accuracy:0.087
# Finish 218 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5544444444444444,0.7722222222222221),the validation accuracy:0.087
# Finish 219 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5544444444444444,0.8811111111111111),the validation accuracy:0.087
# Finish 220 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.5544444444444444,0.99),the validation accuracy:0.087
# Finish 221 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6088888888888889,0.01),the validation accuracy:0.087
# Finish 222 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6088888888888889,0.11888888888888888),the validation accuracy:0.087
# Finish 223 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6088888888888889,0.22777777777777777),the validation accuracy:0.087
# Finish 224 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6088888888888889,0.33666666666666667),the validation accuracy:0.087
# Finish 225 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6088888888888889,0.44555555555555554),the validation accuracy:0.087
# Finish 226 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6088888888888889,0.5544444444444444),the validation accuracy:0.087
# Finish 227 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6088888888888889,0.6633333333333333),the validation accuracy:0.087
# Finish 228 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6088888888888889,0.7722222222222221),the validation accuracy:0.087
# Finish 229 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6088888888888889,0.8811111111111111),the validation accuracy:0.087
# Finish 230 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6088888888888889,0.99),the validation accuracy:0.087
# Finish 231 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6633333333333333,0.01),the validation accuracy:0.087
# Finish 232 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6633333333333333,0.11888888888888888),the validation accuracy:0.087
# Finish 233 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6633333333333333,0.22777777777777777),the validation accuracy:0.087
# Finish 234 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6633333333333333,0.33666666666666667),the validation accuracy:0.087
# Finish 235 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6633333333333333,0.44555555555555554),the validation accuracy:0.087
# Finish 236 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6633333333333333,0.5544444444444444),the validation accuracy:0.087
# Finish 237 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6633333333333333,0.6633333333333333),the validation accuracy:0.087
# Finish 238 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6633333333333333,0.7722222222222221),the validation accuracy:0.087
# Finish 239 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6633333333333333,0.8811111111111111),the validation accuracy:0.087
# Finish 240 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.6633333333333333,0.99),the validation accuracy:0.087
# Finish 241 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7177777777777777,0.01),the validation accuracy:0.087
# Finish 242 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7177777777777777,0.11888888888888888),the validation accuracy:0.087
# Finish 243 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7177777777777777,0.22777777777777777),the validation accuracy:0.087
# Finish 244 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7177777777777777,0.33666666666666667),the validation accuracy:0.087
# Finish 245 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7177777777777777,0.44555555555555554),the validation accuracy:0.087
# Finish 246 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7177777777777777,0.5544444444444444),the validation accuracy:0.087
# Finish 247 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7177777777777777,0.6633333333333333),the validation accuracy:0.087
# Finish 248 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7177777777777777,0.7722222222222221),the validation accuracy:0.087
# Finish 249 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7177777777777777,0.8811111111111111),the validation accuracy:0.087
# Finish 250 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7177777777777777,0.99),the validation accuracy:0.087
# Finish 251 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7722222222222221,0.01),the validation accuracy:0.087
# Finish 252 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7722222222222221,0.11888888888888888),the validation accuracy:0.087
# Finish 253 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7722222222222221,0.22777777777777777),the validation accuracy:0.087
# Finish 254 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7722222222222221,0.33666666666666667),the validation accuracy:0.087
# Finish 255 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7722222222222221,0.44555555555555554),the validation accuracy:0.087
# Finish 256 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7722222222222221,0.5544444444444444),the validation accuracy:0.087
# Finish 257 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7722222222222221,0.6633333333333333),the validation accuracy:0.087
# Finish 258 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7722222222222221,0.7722222222222221),the validation accuracy:0.087
# Finish 259 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7722222222222221,0.8811111111111111),the validation accuracy:0.087
# Finish 260 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.7722222222222221,0.99),the validation accuracy:0.087
# Finish 261 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8266666666666667,0.01),the validation accuracy:0.087
# Finish 262 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8266666666666667,0.11888888888888888),the validation accuracy:0.087
# Finish 263 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8266666666666667,0.22777777777777777),the validation accuracy:0.087
# Finish 264 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8266666666666667,0.33666666666666667),the validation accuracy:0.087
# Finish 265 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8266666666666667,0.44555555555555554),the validation accuracy:0.087
# Finish 266 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8266666666666667,0.5544444444444444),the validation accuracy:0.087
# Finish 267 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8266666666666667,0.6633333333333333),the validation accuracy:0.087
# Finish 268 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8266666666666667,0.7722222222222221),the validation accuracy:0.087
# Finish 269 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8266666666666667,0.8811111111111111),the validation accuracy:0.087
# Finish 270 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8266666666666667,0.99),the validation accuracy:0.087
# Finish 271 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8811111111111111,0.01),the validation accuracy:0.087
# Finish 272 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8811111111111111,0.11888888888888888),the validation accuracy:0.087
# Finish 273 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8811111111111111,0.22777777777777777),the validation accuracy:0.087
# Finish 274 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8811111111111111,0.33666666666666667),the validation accuracy:0.087
# Finish 275 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8811111111111111,0.44555555555555554),the validation accuracy:0.087
# Finish 276 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8811111111111111,0.5544444444444444),the validation accuracy:0.087
# Finish 277 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8811111111111111,0.6633333333333333),the validation accuracy:0.087
# Finish 278 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8811111111111111,0.7722222222222221),the validation accuracy:0.087
# Finish 279 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8811111111111111,0.8811111111111111),the validation accuracy:0.087
# Finish 280 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.8811111111111111,0.99),the validation accuracy:0.087
# Finish 281 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.9355555555555555,0.01),the validation accuracy:0.087
# Finish 282 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.9355555555555555,0.11888888888888888),the validation accuracy:0.087
# Finish 283 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.9355555555555555,0.22777777777777777),the validation accuracy:0.087
# Finish 284 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.9355555555555555,0.33666666666666667),the validation accuracy:0.087
# Finish 285 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.9355555555555555,0.44555555555555554),the validation accuracy:0.087
# Finish 286 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.01061578947368421,0.9355555555555555,0.5544444444444444),the validation accuracy:0.087
# ...
# Finish 510 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.5,0.99),the validation accuracy:0.087
# Finish 511 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.5544444444444444,0.01),the validation accuracy:0.087
# Finish 512 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.5544444444444444,0.11888888888888888),the validation accuracy:0.087
# Finish 513 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.5544444444444444,0.22777777777777777),the validation accuracy:0.087
# Finish 514 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.5544444444444444,0.33666666666666667),the validation accuracy:0.087
# Finish 515 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.5544444444444444,0.44555555555555554),the validation accuracy:0.087
# Finish 516 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.5544444444444444,0.5544444444444444),the validation accuracy:0.087
# Finish 517 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.5544444444444444,0.6633333333333333),the validation accuracy:0.087
# Finish 518 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.5544444444444444,0.7722222222222221),the validation accuracy:0.087
# Finish 519 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.5544444444444444,0.8811111111111111),the validation accuracy:0.087
# Finish 520 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.5544444444444444,0.99),the validation accuracy:0.087
# Finish 521 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6088888888888889,0.01),the validation accuracy:0.087
# Finish 522 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6088888888888889,0.11888888888888888),the validation accuracy:0.087
# Finish 523 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6088888888888889,0.22777777777777777),the validation accuracy:0.087
# Finish 524 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6088888888888889,0.33666666666666667),the validation accuracy:0.087
# Finish 525 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6088888888888889,0.44555555555555554),the validation accuracy:0.087
# Finish 526 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6088888888888889,0.5544444444444444),the validation accuracy:0.087
# Finish 527 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6088888888888889,0.6633333333333333),the validation accuracy:0.087
# Finish 528 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6088888888888889,0.7722222222222221),the validation accuracy:0.087
# Finish 529 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6088888888888889,0.8811111111111111),the validation accuracy:0.087
# Finish 530 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6088888888888889,0.99),the validation accuracy:0.087
# Finish 531 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6633333333333333,0.01),the validation accuracy:0.087
# Finish 532 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6633333333333333,0.11888888888888888),the validation accuracy:0.087
# Finish 533 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6633333333333333,0.22777777777777777),the validation accuracy:0.087
# Finish 534 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6633333333333333,0.33666666666666667),the validation accuracy:0.087
# Finish 535 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6633333333333333,0.44555555555555554),the validation accuracy:0.087
# Finish 536 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6633333333333333,0.5544444444444444),the validation accuracy:0.087
# Finish 537 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6633333333333333,0.6633333333333333),the validation accuracy:0.087
# Finish 538 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6633333333333333,0.7722222222222221),the validation accuracy:0.087
# Finish 539 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6633333333333333,0.8811111111111111),the validation accuracy:0.087
# Finish 540 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.6633333333333333,0.99),the validation accuracy:0.087
# Finish 541 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7177777777777777,0.01),the validation accuracy:0.087
# Finish 542 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7177777777777777,0.11888888888888888),the validation accuracy:0.087
# Finish 543 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7177777777777777,0.22777777777777777),the validation accuracy:0.087
# Finish 544 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7177777777777777,0.33666666666666667),the validation accuracy:0.087
# Finish 545 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7177777777777777,0.44555555555555554),the validation accuracy:0.087
# Finish 546 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7177777777777777,0.5544444444444444),the validation accuracy:0.087
# Finish 547 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7177777777777777,0.6633333333333333),the validation accuracy:0.087
# D:\Leon-Ma\000-Personal\cs231n\assignment1\cs231n\classifiers\neural_net.py:103: RuntimeWarning: overflow encountered in square
#   loss += 0.5 * reg * (np.sum(np.square(W1)) + np.sum(np.square(W2)))
# Finish 548 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7177777777777777,0.7722222222222221),the validation accuracy:0.087
# Finish 549 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7177777777777777,0.8811111111111111),the validation accuracy:0.087
# Finish 550 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7177777777777777,0.99),the validation accuracy:0.087
# Finish 551 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7722222222222221,0.01),the validation accuracy:0.087
# Finish 552 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7722222222222221,0.11888888888888888),the validation accuracy:0.087
# Finish 553 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7722222222222221,0.22777777777777777),the validation accuracy:0.087
# Finish 554 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7722222222222221,0.33666666666666667),the validation accuracy:0.087
# Finish 555 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7722222222222221,0.44555555555555554),the validation accuracy:0.087
# Finish 556 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7722222222222221,0.5544444444444444),the validation accuracy:0.087
# Finish 557 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7722222222222221,0.6633333333333333),the validation accuracy:0.087
# Finish 558 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7722222222222221,0.7722222222222221),the validation accuracy:0.087
# Finish 559 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7722222222222221,0.8811111111111111),the validation accuracy:0.087
# Finish 560 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.7722222222222221,0.99),the validation accuracy:0.087
# Finish 561 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8266666666666667,0.01),the validation accuracy:0.087
# Finish 562 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8266666666666667,0.11888888888888888),the validation accuracy:0.087
# Finish 563 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8266666666666667,0.22777777777777777),the validation accuracy:0.087
# Finish 564 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8266666666666667,0.33666666666666667),the validation accuracy:0.087
# Finish 565 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8266666666666667,0.44555555555555554),the validation accuracy:0.087
# Finish 566 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8266666666666667,0.5544444444444444),the validation accuracy:0.087
# Finish 567 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8266666666666667,0.6633333333333333),the validation accuracy:0.087
# Finish 568 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8266666666666667,0.7722222222222221),the validation accuracy:0.087
# Finish 569 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8266666666666667,0.8811111111111111),the validation accuracy:0.087
# Finish 570 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8266666666666667,0.99),the validation accuracy:0.087
# Finish 571 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8811111111111111,0.01),the validation accuracy:0.087
# Finish 572 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8811111111111111,0.11888888888888888),the validation accuracy:0.087
# Finish 573 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8811111111111111,0.22777777777777777),the validation accuracy:0.087
# Finish 574 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8811111111111111,0.33666666666666667),the validation accuracy:0.087
# Finish 575 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8811111111111111,0.44555555555555554),the validation accuracy:0.087
# Finish 576 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8811111111111111,0.5544444444444444),the validation accuracy:0.087
# Finish 577 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8811111111111111,0.6633333333333333),the validation accuracy:0.087
# Finish 578 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8811111111111111,0.7722222222222221),the validation accuracy:0.087
# Finish 579 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8811111111111111,0.8811111111111111),the validation accuracy:0.087
# Finish 580 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.8811111111111111,0.99),the validation accuracy:0.087
# Finish 581 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.9355555555555555,0.01),the validation accuracy:0.087
# Finish 582 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.9355555555555555,0.11888888888888888),the validation accuracy:0.087
# Finish 583 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.9355555555555555,0.22777777777777777),the validation accuracy:0.087
# Finish 584 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.9355555555555555,0.33666666666666667),the validation accuracy:0.087
# Finish 585 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.9355555555555555,0.44555555555555554),the validation accuracy:0.087
# Finish 586 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.9355555555555555,0.5544444444444444),the validation accuracy:0.087
# D:\Leon-Ma\000-Personal\cs231n\assignment1\cs231n\classifiers\neural_net.py:103: RuntimeWarning: overflow encountered in double_scalars
#   loss += 0.5 * reg * (np.sum(np.square(W1)) + np.sum(np.square(W2)))
# Finish 587 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.9355555555555555,0.6633333333333333),the validation accuracy:0.087
# Finish 588 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.9355555555555555,0.7722222222222221),the validation accuracy:0.087
# Finish 589 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.9355555555555555,0.8811111111111111),the validation accuracy:0.087
# Finish 590 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.9355555555555555,0.99),the validation accuracy:0.087
# Finish 591 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.99,0.01),the validation accuracy:0.087
# Finish 592 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.99,0.11888888888888888),the validation accuracy:0.087
# Finish 593 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.99,0.22777777777777777),the validation accuracy:0.087
# Finish 594 (hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = (20,100,0.02638947368421053,0.99,0.33666666666666667),the validation accuracy:0.087
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-2e7b9fadd126> in <module>()
#      31                     net = TwoLayerNet(input_size, hds, num_classes)
#      32                     stats = net.train(X_train, y_train, X_val, y_val, num_iters=2000, batch_size=bs,learning_rate=lr, learning_rate_decay=lrd,
# ---> 33                         reg=reg, verbose=False)
#      34                     val_acc = (net.predict(X_val) == y_val).mean()
#      35                     if val_acc > best_val:
#
# D:\Leon-Ma\000-Personal\cs231n\assignment1\cs231n\classifiers\neural_net.py in train(self, X, y, X_val, y_val, learning_rate, learning_rate_decay, reg, num_iters, batch_size, verbose)
#     169       #########################################################################
#     170       batch_idx = np.random.choice(num_train, batch_size,  replace = True)
# --> 171       X_batch = X[batch_idx]
#     172       y_batch = y[batch_idx]
#     173       #########################################################################
#
# KeyboardInterrupt:

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
best_params = None
best_stats = None
for k, v in result.items():
    if v[1] >= 0.482 :
        best_params = k
        best_stats = v[0]

print('Best params(hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg)=({})),the val_acc:{} '.format(best_params, best_val))

stats = best_stats
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()
# Out:
# Test accuracy:  0.46
# Best params(hiddenSize, BatchSize, LearningRate, LearningRateDecay, Reg) = ((20, 100, 0.0053578947368421058, 0.5, 0.55444444444444441))),the validation accuracy:0.482
