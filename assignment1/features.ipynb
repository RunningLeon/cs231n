# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *
num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# ERROR:root:No traceback has been produced, nothing to debug.
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        svm = LinearSVM()
        svm.train(X_train_feats, y_train, learning_rate=lr, reg=reg, num_iters=2000, verbose=True)
        y_val_pred = svm.predict(X_val_feats)
        y_train_pred = svm.predict(X_train_feats)
        val_acc = np.mean(y_val == y_val_pred)
        train_acc = np.mean(y_train_pred == y_train)
        if best_val < val_acc:
            best_val = val_acc
            best_svm = svm
        results[(lr, reg)] = (train_acc, val_acc)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 2000: loss 48.155256
# iteration 100 / 2000: loss 47.761781
# iteration 200 / 2000: loss 47.368034
# iteration 300 / 2000: loss 46.990126
# iteration 400 / 2000: loss 46.615379
# iteration 500 / 2000: loss 46.246867
# iteration 600 / 2000: loss 45.872089
# iteration 700 / 2000: loss 45.499229
# iteration 800 / 2000: loss 45.159747
# iteration 900 / 2000: loss 44.789371
# iteration 1000 / 2000: loss 44.439169
# iteration 1100 / 2000: loss 44.064209
# iteration 1200 / 2000: loss 43.724417
# iteration 1300 / 2000: loss 43.369515
# iteration 1400 / 2000: loss 43.031025
# iteration 1500 / 2000: loss 42.710290
# iteration 1600 / 2000: loss 42.346749
# iteration 1700 / 2000: loss 42.044877
# iteration 1800 / 2000: loss 41.705754
# iteration 1900 / 2000: loss 41.378820
# iteration 0 / 2000: loss 400.991384
# iteration 100 / 2000: loss 363.675767
# iteration 200 / 2000: loss 329.906314
# iteration 300 / 2000: loss 299.372176
# iteration 400 / 2000: loss 271.729775
# iteration 500 / 2000: loss 246.728182
# iteration 600 / 2000: loss 224.098247
# iteration 700 / 2000: loss 203.612751
# iteration 800 / 2000: loss 185.089964
# iteration 900 / 2000: loss 168.327940
# iteration 1000 / 2000: loss 153.165815
# iteration 1100 / 2000: loss 139.442536
# iteration 1200 / 2000: loss 127.034851
# iteration 1300 / 2000: loss 115.791994
# iteration 1400 / 2000: loss 105.633585
# iteration 1500 / 2000: loss 96.426229
# iteration 1600 / 2000: loss 88.105929
# iteration 1700 / 2000: loss 80.573776
# iteration 1800 / 2000: loss 73.770709
# iteration 1900 / 2000: loss 67.596262
# iteration 0 / 2000: loss 3969.293844
# iteration 100 / 2000: loss 1462.256808
# iteration 200 / 2000: loss 542.286487
# iteration 300 / 2000: loss 204.694938
# iteration 400 / 2000: loss 80.809796
# iteration 500 / 2000: loss 35.352816
# iteration 600 / 2000: loss 18.669707
# iteration 700 / 2000: loss 12.548104
# iteration 800 / 2000: loss 10.302140
# iteration 900 / 2000: loss 9.477786
# iteration 1000 / 2000: loss 9.175321
# iteration 1100 / 2000: loss 9.064362
# iteration 1200 / 2000: loss 9.023615
# iteration 1300 / 2000: loss 9.008674
# iteration 1400 / 2000: loss 9.003168
# iteration 1500 / 2000: loss 9.001161
# iteration 1600 / 2000: loss 9.000425
# iteration 1700 / 2000: loss 9.000152
# iteration 1800 / 2000: loss 9.000049
# iteration 1900 / 2000: loss 9.000015
# iteration 0 / 2000: loss 46.478197
# iteration 100 / 2000: loss 42.903953
# iteration 200 / 2000: loss 39.662631
# iteration 300 / 2000: loss 36.758579
# iteration 400 / 2000: loss 34.112914
# iteration 500 / 2000: loss 31.730704
# iteration 600 / 2000: loss 29.558592
# iteration 700 / 2000: loss 27.593944
# iteration 800 / 2000: loss 25.839149
# iteration 900 / 2000: loss 24.232268
# iteration 1000 / 2000: loss 22.785938
# iteration 1100 / 2000: loss 21.472517
# iteration 1200 / 2000: loss 20.282901
# iteration 1300 / 2000: loss 19.205026
# iteration 1400 / 2000: loss 18.232444
# iteration 1500 / 2000: loss 17.353313
# iteration 1600 / 2000: loss 16.563387
# iteration 1700 / 2000: loss 15.849588
# iteration 1800 / 2000: loss 15.191531
# iteration 1900 / 2000: loss 14.596571
# iteration 0 / 2000: loss 393.088058
# iteration 100 / 2000: loss 149.944599
# iteration 200 / 2000: loss 60.719990
# iteration 300 / 2000: loss 27.978880
# iteration 400 / 2000: loss 15.964263
# iteration 500 / 2000: loss 11.556807
# iteration 600 / 2000: loss 9.937592
# iteration 700 / 2000: loss 9.344506
# iteration 800 / 2000: loss 9.126098
# iteration 900 / 2000: loss 9.046228
# iteration 1000 / 2000: loss 9.016996
# iteration 1100 / 2000: loss 9.006165
# iteration 1200 / 2000: loss 9.002199
# iteration 1300 / 2000: loss 9.000801
# iteration 1400 / 2000: loss 9.000223
# iteration 1500 / 2000: loss 9.000051
# iteration 1600 / 2000: loss 8.999969
# iteration 1700 / 2000: loss 8.999941
# iteration 1800 / 2000: loss 8.999930
# iteration 1900 / 2000: loss 8.999942
# iteration 0 / 2000: loss 4067.814750
# iteration 100 / 2000: loss 9.142344
# iteration 200 / 2000: loss 8.999998
# iteration 300 / 2000: loss 8.999994
# iteration 400 / 2000: loss 8.999994
# iteration 500 / 2000: loss 8.999994
# iteration 600 / 2000: loss 8.999992
# iteration 700 / 2000: loss 8.999992
# iteration 800 / 2000: loss 8.999994
# iteration 900 / 2000: loss 8.999992
# iteration 1000 / 2000: loss 8.999994
# iteration 1100 / 2000: loss 8.999992
# iteration 1200 / 2000: loss 8.999993
# iteration 1300 / 2000: loss 8.999994
# iteration 1400 / 2000: loss 8.999994
# iteration 1500 / 2000: loss 8.999992
# iteration 1600 / 2000: loss 8.999992
# iteration 1700 / 2000: loss 8.999992
# iteration 1800 / 2000: loss 8.999993
# iteration 1900 / 2000: loss 8.999993
# iteration 0 / 2000: loss 48.137503
# iteration 100 / 2000: loss 23.366749
# iteration 200 / 2000: loss 14.268876
# iteration 300 / 2000: loss 10.936704
# iteration 400 / 2000: loss 9.708805
# iteration 500 / 2000: loss 9.259951
# iteration 600 / 2000: loss 9.094552
# iteration 700 / 2000: loss 9.034543
# iteration 800 / 2000: loss 9.011905
# iteration 900 / 2000: loss 9.003926
# iteration 1000 / 2000: loss 9.000995
# iteration 1100 / 2000: loss 9.000061
# iteration 1200 / 2000: loss 8.999611
# iteration 1300 / 2000: loss 8.999245
# iteration 1400 / 2000: loss 8.999217
# iteration 1500 / 2000: loss 8.999226
# iteration 1600 / 2000: loss 8.999325
# iteration 1700 / 2000: loss 8.999270
# iteration 1800 / 2000: loss 8.999303
# iteration 1900 / 2000: loss 8.999329
# iteration 0 / 2000: loss 407.189071
# iteration 100 / 2000: loss 9.013918
# iteration 200 / 2000: loss 8.999943
# iteration 300 / 2000: loss 8.999931
# iteration 400 / 2000: loss 8.999935
# iteration 500 / 2000: loss 8.999918
# iteration 600 / 2000: loss 8.999926
# iteration 700 / 2000: loss 8.999937
# iteration 800 / 2000: loss 8.999945
# iteration 900 / 2000: loss 8.999916
# iteration 1000 / 2000: loss 8.999927
# iteration 1100 / 2000: loss 8.999939
# iteration 1200 / 2000: loss 8.999936
# iteration 1300 / 2000: loss 8.999942
# iteration 1400 / 2000: loss 8.999941
# iteration 1500 / 2000: loss 8.999934
# iteration 1600 / 2000: loss 8.999931
# iteration 1700 / 2000: loss 8.999945
# iteration 1800 / 2000: loss 8.999938
# iteration 1900 / 2000: loss 8.999922
# iteration 0 / 2000: loss 4173.368614
# iteration 100 / 2000: loss 8.999996
# iteration 200 / 2000: loss 8.999995
# iteration 300 / 2000: loss 8.999996
# iteration 400 / 2000: loss 8.999996
# iteration 500 / 2000: loss 8.999996
# iteration 600 / 2000: loss 8.999994
# iteration 700 / 2000: loss 8.999997
# iteration 800 / 2000: loss 8.999995
# iteration 900 / 2000: loss 8.999994
# iteration 1000 / 2000: loss 8.999995
# iteration 1100 / 2000: loss 8.999995
# iteration 1200 / 2000: loss 8.999996
# iteration 1300 / 2000: loss 8.999996
# iteration 1400 / 2000: loss 8.999994
# iteration 1500 / 2000: loss 8.999995
# iteration 1600 / 2000: loss 8.999995
# iteration 1700 / 2000: loss 8.999995
# iteration 1800 / 2000: loss 8.999996
# iteration 1900 / 2000: loss 8.999995
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.093204 val accuracy: 0.103000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.110224 val accuracy: 0.117000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.354184 val accuracy: 0.360000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.087061 val accuracy: 0.083000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.412245 val accuracy: 0.407000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.415082 val accuracy: 0.410000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.415816 val accuracy: 0.418000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.412449 val accuracy: 0.408000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.363020 val accuracy: 0.350000
# best validation accuracy achieved during cross-validation: 0.418000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.424

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print(X_train_feats.shape)
# Out:
# (49000, 155)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None
################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
learning_rates = np.linspace(0.1, 0.001, 10)
learning_rate_decays = np.linspace(0.8, 0.99, 5)
regs = np.linspace(0.2, 0.9, 10)
best_val = -1
result = {'best_params':None}
num_i = 0
num_total = len(learning_rates)*len(learning_rate_decays)*len(regs)
for lr in learning_rates:
    for lrd in learning_rate_decays:
        for reg in regs:
            stats = net.train(X_train_feats, y_train, X_val_feats, y_val, lr, lrd, reg, 
                      num_iters=2000)
            y_train_pred = net.predict(X_train_feats)
            y_val_pred = net.predict(X_val_feats)
            train_acc = np.mean(y_train == y_train_pred)
            val_acc = np.mean(y_val == y_val_pred)
            if best_val < val_acc:
                best_val = val_acc
                best_net = net
                result['best_params'] = (lr, lrd, reg)
            num_i += 1
            print('Finish {} of {} iterations, val_acc={} '.format(num_i, num_total, val_acc))
            
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# Finish 1 of 500 iterations, val_acc=0.301
# Finish 2 of 500 iterations, val_acc=0.3
# Finish 3 of 500 iterations, val_acc=0.279
# Finish 4 of 500 iterations, val_acc=0.243
# Finish 5 of 500 iterations, val_acc=0.168
# Finish 6 of 500 iterations, val_acc=0.143
# Finish 7 of 500 iterations, val_acc=0.11
# Finish 8 of 500 iterations, val_acc=0.078
# Finish 9 of 500 iterations, val_acc=0.079
# Finish 10 of 500 iterations, val_acc=0.105
# Finish 11 of 500 iterations, val_acc=0.196
# Finish 12 of 500 iterations, val_acc=0.22
# Finish 13 of 500 iterations, val_acc=0.266
# Finish 14 of 500 iterations, val_acc=0.229
# Finish 15 of 500 iterations, val_acc=0.198
# Finish 16 of 500 iterations, val_acc=0.139
# Finish 17 of 500 iterations, val_acc=0.113
# Finish 18 of 500 iterations, val_acc=0.087
# Finish 19 of 500 iterations, val_acc=0.105
# Finish 20 of 500 iterations, val_acc=0.107
# Finish 21 of 500 iterations, val_acc=0.229
# Finish 22 of 500 iterations, val_acc=0.265
# Finish 23 of 500 iterations, val_acc=0.286
# Finish 24 of 500 iterations, val_acc=0.228
# Finish 25 of 500 iterations, val_acc=0.193
# Finish 26 of 500 iterations, val_acc=0.137
# Finish 27 of 500 iterations, val_acc=0.107
# Finish 28 of 500 iterations, val_acc=0.119
# Finish 29 of 500 iterations, val_acc=0.112
# Finish 30 of 500 iterations, val_acc=0.107
# Finish 31 of 500 iterations, val_acc=0.206
# Finish 32 of 500 iterations, val_acc=0.262
# Finish 33 of 500 iterations, val_acc=0.29
# Finish 34 of 500 iterations, val_acc=0.255
# Finish 35 of 500 iterations, val_acc=0.171
# Finish 36 of 500 iterations, val_acc=0.183
# Finish 37 of 500 iterations, val_acc=0.119
# Finish 38 of 500 iterations, val_acc=0.079
# Finish 39 of 500 iterations, val_acc=0.112
# Finish 40 of 500 iterations, val_acc=0.102
# Finish 41 of 500 iterations, val_acc=0.288
# Finish 42 of 500 iterations, val_acc=0.268
# Finish 43 of 500 iterations, val_acc=0.27
# Finish 44 of 500 iterations, val_acc=0.245
# Finish 45 of 500 iterations, val_acc=0.146
# Finish 46 of 500 iterations, val_acc=0.12
# Finish 47 of 500 iterations, val_acc=0.113
# Finish 48 of 500 iterations, val_acc=0.107
# Finish 49 of 500 iterations, val_acc=0.078
# Finish 50 of 500 iterations, val_acc=0.078
# Finish 51 of 500 iterations, val_acc=0.199
# Finish 52 of 500 iterations, val_acc=0.198
# Finish 53 of 500 iterations, val_acc=0.289
# Finish 54 of 500 iterations, val_acc=0.254
# Finish 55 of 500 iterations, val_acc=0.206
# Finish 56 of 500 iterations, val_acc=0.204
# Finish 57 of 500 iterations, val_acc=0.094
# Finish 58 of 500 iterations, val_acc=0.14
# Finish 59 of 500 iterations, val_acc=0.078
# Finish 60 of 500 iterations, val_acc=0.119
# Finish 61 of 500 iterations, val_acc=0.194
# Finish 62 of 500 iterations, val_acc=0.269
# Finish 63 of 500 iterations, val_acc=0.274
# Finish 64 of 500 iterations, val_acc=0.24
# Finish 65 of 500 iterations, val_acc=0.213
# Finish 66 of 500 iterations, val_acc=0.157
# Finish 67 of 500 iterations, val_acc=0.105
# Finish 68 of 500 iterations, val_acc=0.105
# Finish 69 of 500 iterations, val_acc=0.119
# Finish 70 of 500 iterations, val_acc=0.102
# Finish 71 of 500 iterations, val_acc=0.209
# Finish 72 of 500 iterations, val_acc=0.293
# Finish 73 of 500 iterations, val_acc=0.274
# Finish 74 of 500 iterations, val_acc=0.269
# Finish 75 of 500 iterations, val_acc=0.2
# Finish 76 of 500 iterations, val_acc=0.202
# Finish 77 of 500 iterations, val_acc=0.173
# Finish 78 of 500 iterations, val_acc=0.105
# Finish 79 of 500 iterations, val_acc=0.078
# Finish 80 of 500 iterations, val_acc=0.079
# Finish 81 of 500 iterations, val_acc=0.298
# Finish 82 of 500 iterations, val_acc=0.27
# Finish 83 of 500 iterations, val_acc=0.263
# Finish 84 of 500 iterations, val_acc=0.26
# Finish 85 of 500 iterations, val_acc=0.196
# Finish 86 of 500 iterations, val_acc=0.173
# Finish 87 of 500 iterations, val_acc=0.112
# Finish 88 of 500 iterations, val_acc=0.079
# Finish 89 of 500 iterations, val_acc=0.119
# Finish 90 of 500 iterations, val_acc=0.113
# Finish 91 of 500 iterations, val_acc=0.281
# Finish 92 of 500 iterations, val_acc=0.268
# Finish 93 of 500 iterations, val_acc=0.274
# Finish 94 of 500 iterations, val_acc=0.239
# Finish 95 of 500 iterations, val_acc=0.207
# Finish 96 of 500 iterations, val_acc=0.087
# Finish 97 of 500 iterations, val_acc=0.098
# Finish 98 of 500 iterations, val_acc=0.087
# Finish 99 of 500 iterations, val_acc=0.098
# Finish 100 of 500 iterations, val_acc=0.078
# Finish 101 of 500 iterations, val_acc=0.119
# Finish 102 of 500 iterations, val_acc=0.199
# Finish 103 of 500 iterations, val_acc=0.268
# Finish 104 of 500 iterations, val_acc=0.234
# Finish 105 of 500 iterations, val_acc=0.195
# Finish 106 of 500 iterations, val_acc=0.19
# Finish 107 of 500 iterations, val_acc=0.191
# Finish 108 of 500 iterations, val_acc=0.078
# Finish 109 of 500 iterations, val_acc=0.123
# Finish 110 of 500 iterations, val_acc=0.079
# Finish 111 of 500 iterations, val_acc=0.203
# Finish 112 of 500 iterations, val_acc=0.21
# Finish 113 of 500 iterations, val_acc=0.281
# Finish 114 of 500 iterations, val_acc=0.242
# Finish 115 of 500 iterations, val_acc=0.2
# Finish 116 of 500 iterations, val_acc=0.154
# Finish 117 of 500 iterations, val_acc=0.1
# Finish 118 of 500 iterations, val_acc=0.113
# Finish 119 of 500 iterations, val_acc=0.119
# Finish 120 of 500 iterations, val_acc=0.079
# Finish 121 of 500 iterations, val_acc=0.213
# Finish 122 of 500 iterations, val_acc=0.282
# Finish 123 of 500 iterations, val_acc=0.296
# Finish 124 of 500 iterations, val_acc=0.228
# Finish 125 of 500 iterations, val_acc=0.197
# Finish 126 of 500 iterations, val_acc=0.173
# Finish 127 of 500 iterations, val_acc=0.12
# Finish 128 of 500 iterations, val_acc=0.087
# Finish 129 of 500 iterations, val_acc=0.078
# Finish 130 of 500 iterations, val_acc=0.105
# Finish 131 of 500 iterations, val_acc=0.27
# Finish 132 of 500 iterations, val_acc=0.273
# Finish 133 of 500 iterations, val_acc=0.277
# Finish 134 of 500 iterations, val_acc=0.256
# Finish 135 of 500 iterations, val_acc=0.179
# Finish 136 of 500 iterations, val_acc=0.142
# Finish 137 of 500 iterations, val_acc=0.132
# Finish 138 of 500 iterations, val_acc=0.098
# Finish 139 of 500 iterations, val_acc=0.112
# Finish 140 of 500 iterations, val_acc=0.119
# Finish 141 of 500 iterations, val_acc=0.31
# Finish 142 of 500 iterations, val_acc=0.283
# Finish 143 of 500 iterations, val_acc=0.276
# Finish 144 of 500 iterations, val_acc=0.183
# Finish 145 of 500 iterations, val_acc=0.195
# Finish 146 of 500 iterations, val_acc=0.191
# Finish 147 of 500 iterations, val_acc=0.134
# Finish 148 of 500 iterations, val_acc=0.107
# Finish 149 of 500 iterations, val_acc=0.087
# Finish 150 of 500 iterations, val_acc=0.107
# Finish 151 of 500 iterations, val_acc=0.087
# Finish 152 of 500 iterations, val_acc=0.197
# Finish 153 of 500 iterations, val_acc=0.214
# Finish 154 of 500 iterations, val_acc=0.224
# Finish 155 of 500 iterations, val_acc=0.22
# Finish 156 of 500 iterations, val_acc=0.176
# Finish 157 of 500 iterations, val_acc=0.192
# Finish 158 of 500 iterations, val_acc=0.102
# Finish 159 of 500 iterations, val_acc=0.102
# Finish 160 of 500 iterations, val_acc=0.112
# Finish 161 of 500 iterations, val_acc=0.205
# Finish 162 of 500 iterations, val_acc=0.201
# Finish 163 of 500 iterations, val_acc=0.249
# Finish 164 of 500 iterations, val_acc=0.262
# Finish 165 of 500 iterations, val_acc=0.201
# Finish 166 of 500 iterations, val_acc=0.154
# Finish 167 of 500 iterations, val_acc=0.137
# Finish 168 of 500 iterations, val_acc=0.078
# Finish 169 of 500 iterations, val_acc=0.112
# Finish 170 of 500 iterations, val_acc=0.079
# Finish 171 of 500 iterations, val_acc=0.211
# Finish 172 of 500 iterations, val_acc=0.279
# Finish 173 of 500 iterations, val_acc=0.295
# Finish 174 of 500 iterations, val_acc=0.245
# Finish 175 of 500 iterations, val_acc=0.197
# Finish 176 of 500 iterations, val_acc=0.168
# Finish 177 of 500 iterations, val_acc=0.116
# Finish 178 of 500 iterations, val_acc=0.079
# Finish 179 of 500 iterations, val_acc=0.102
# Finish 180 of 500 iterations, val_acc=0.098
# Finish 181 of 500 iterations, val_acc=0.203
# Finish 182 of 500 iterations, val_acc=0.294
# Finish 183 of 500 iterations, val_acc=0.254
# Finish 184 of 500 iterations, val_acc=0.236
# Finish 185 of 500 iterations, val_acc=0.214
# Finish 186 of 500 iterations, val_acc=0.207
# Finish 187 of 500 iterations, val_acc=0.107
# Finish 188 of 500 iterations, val_acc=0.113
# Finish 189 of 500 iterations, val_acc=0.079
# Finish 190 of 500 iterations, val_acc=0.105
# Finish 191 of 500 iterations, val_acc=0.26
# Finish 192 of 500 iterations, val_acc=0.274
# Finish 193 of 500 iterations, val_acc=0.277
# Finish 194 of 500 iterations, val_acc=0.224
# Finish 195 of 500 iterations, val_acc=0.19
# Finish 196 of 500 iterations, val_acc=0.181
# Finish 197 of 500 iterations, val_acc=0.113
# Finish 198 of 500 iterations, val_acc=0.107
# Finish 199 of 500 iterations, val_acc=0.113
# Finish 200 of 500 iterations, val_acc=0.078
# Finish 201 of 500 iterations, val_acc=0.093
# Finish 202 of 500 iterations, val_acc=0.198
# Finish 203 of 500 iterations, val_acc=0.206
# Finish 204 of 500 iterations, val_acc=0.212
# Finish 205 of 500 iterations, val_acc=0.199
# Finish 206 of 500 iterations, val_acc=0.192
# Finish 207 of 500 iterations, val_acc=0.092
# Finish 208 of 500 iterations, val_acc=0.132
# Finish 209 of 500 iterations, val_acc=0.079
# Finish 210 of 500 iterations, val_acc=0.087
# Finish 211 of 500 iterations, val_acc=0.188
# Finish 212 of 500 iterations, val_acc=0.208
# Finish 213 of 500 iterations, val_acc=0.202
# Finish 214 of 500 iterations, val_acc=0.192
# Finish 215 of 500 iterations, val_acc=0.193
# Finish 216 of 500 iterations, val_acc=0.206
# Finish 217 of 500 iterations, val_acc=0.119
# Finish 218 of 500 iterations, val_acc=0.095
# Finish 219 of 500 iterations, val_acc=0.098
# Finish 220 of 500 iterations, val_acc=0.107
# Finish 221 of 500 iterations, val_acc=0.195
# Finish 222 of 500 iterations, val_acc=0.206
# Finish 223 of 500 iterations, val_acc=0.278
# Finish 224 of 500 iterations, val_acc=0.233
# Finish 225 of 500 iterations, val_acc=0.209
# Finish 226 of 500 iterations, val_acc=0.194
# Finish 227 of 500 iterations, val_acc=0.156
# Finish 228 of 500 iterations, val_acc=0.087
# Finish 229 of 500 iterations, val_acc=0.098
# Finish 230 of 500 iterations, val_acc=0.079
# Finish 231 of 500 iterations, val_acc=0.204
# Finish 232 of 500 iterations, val_acc=0.195
# Finish 233 of 500 iterations, val_acc=0.273
# Finish 234 of 500 iterations, val_acc=0.256
# Finish 235 of 500 iterations, val_acc=0.195
# Finish 236 of 500 iterations, val_acc=0.185
# Finish 237 of 500 iterations, val_acc=0.119
# Finish 238 of 500 iterations, val_acc=0.113
# Finish 239 of 500 iterations, val_acc=0.107
# Finish 240 of 500 iterations, val_acc=0.113
# Finish 241 of 500 iterations, val_acc=0.211
# Finish 242 of 500 iterations, val_acc=0.284
# Finish 243 of 500 iterations, val_acc=0.271
# Finish 244 of 500 iterations, val_acc=0.222
# Finish 245 of 500 iterations, val_acc=0.191
# Finish 246 of 500 iterations, val_acc=0.131
# Finish 247 of 500 iterations, val_acc=0.098
# Finish 248 of 500 iterations, val_acc=0.078
# Finish 249 of 500 iterations, val_acc=0.079
# Finish 250 of 500 iterations, val_acc=0.098
# Finish 251 of 500 iterations, val_acc=0.098
# Finish 252 of 500 iterations, val_acc=0.185
# Finish 253 of 500 iterations, val_acc=0.196
# Finish 254 of 500 iterations, val_acc=0.201
# Finish 255 of 500 iterations, val_acc=0.192
# Finish 256 of 500 iterations, val_acc=0.177
# Finish 257 of 500 iterations, val_acc=0.128
# Finish 258 of 500 iterations, val_acc=0.113
# Finish 259 of 500 iterations, val_acc=0.119
# Finish 260 of 500 iterations, val_acc=0.142
# Finish 261 of 500 iterations, val_acc=0.2
# Finish 262 of 500 iterations, val_acc=0.199
# Finish 263 of 500 iterations, val_acc=0.202
# Finish 264 of 500 iterations, val_acc=0.195
# Finish 265 of 500 iterations, val_acc=0.181
# Finish 266 of 500 iterations, val_acc=0.187
# Finish 267 of 500 iterations, val_acc=0.117
# Finish 268 of 500 iterations, val_acc=0.113
# Finish 269 of 500 iterations, val_acc=0.087
# Finish 270 of 500 iterations, val_acc=0.113
# Finish 271 of 500 iterations, val_acc=0.199
# Finish 272 of 500 iterations, val_acc=0.2
# Finish 273 of 500 iterations, val_acc=0.207
# Finish 274 of 500 iterations, val_acc=0.205
# Finish 275 of 500 iterations, val_acc=0.196
# Finish 276 of 500 iterations, val_acc=0.199
# Finish 277 of 500 iterations, val_acc=0.141
# Finish 278 of 500 iterations, val_acc=0.119
# Finish 279 of 500 iterations, val_acc=0.107
# Finish 280 of 500 iterations, val_acc=0.102
# Finish 281 of 500 iterations, val_acc=0.204
# Finish 282 of 500 iterations, val_acc=0.205
# Finish 283 of 500 iterations, val_acc=0.218
# Finish 284 of 500 iterations, val_acc=0.267
# Finish 285 of 500 iterations, val_acc=0.187
# Finish 286 of 500 iterations, val_acc=0.176
# Finish 287 of 500 iterations, val_acc=0.156
# Finish 288 of 500 iterations, val_acc=0.19
# Finish 289 of 500 iterations, val_acc=0.078
# Finish 290 of 500 iterations, val_acc=0.105
# Finish 291 of 500 iterations, val_acc=0.202
# Finish 292 of 500 iterations, val_acc=0.285
# Finish 293 of 500 iterations, val_acc=0.278
# Finish 294 of 500 iterations, val_acc=0.257
# Finish 295 of 500 iterations, val_acc=0.222
# Finish 296 of 500 iterations, val_acc=0.211
# Finish 297 of 500 iterations, val_acc=0.098
# Finish 298 of 500 iterations, val_acc=0.109
# Finish 299 of 500 iterations, val_acc=0.079
# Finish 300 of 500 iterations, val_acc=0.098
# Finish 301 of 500 iterations, val_acc=0.102
# Finish 302 of 500 iterations, val_acc=0.112
# Finish 303 of 500 iterations, val_acc=0.124
# Finish 304 of 500 iterations, val_acc=0.19
# Finish 305 of 500 iterations, val_acc=0.194
# Finish 306 of 500 iterations, val_acc=0.164
# Finish 307 of 500 iterations, val_acc=0.106
# Finish 308 of 500 iterations, val_acc=0.119
# Finish 309 of 500 iterations, val_acc=0.087
# Finish 310 of 500 iterations, val_acc=0.087
# Finish 311 of 500 iterations, val_acc=0.195
# Finish 312 of 500 iterations, val_acc=0.204
# Finish 313 of 500 iterations, val_acc=0.199
# Finish 314 of 500 iterations, val_acc=0.205
# Finish 315 of 500 iterations, val_acc=0.194
# Finish 316 of 500 iterations, val_acc=0.192
# Finish 317 of 500 iterations, val_acc=0.097
# Finish 318 of 500 iterations, val_acc=0.114
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-2f3ac8036904> in <module>()
#      23         for reg in regs:
#      24             stats = net.train(X_train_feats, y_train, X_val_feats, y_val, lr, lrd, reg,
# ---> 25                       num_iters=2000)
#      26             y_train_pred = net.predict(X_train_feats)
#      27             y_val_pred = net.predict(X_val_feats)
#
# D:\Leon-Ma\000-Personal\cs231n\assignment1\cs231n\classifiers\neural_net.py in train(self, X, y, X_val, y_val, learning_rate, learning_rate_decay, reg, num_iters, batch_size, verbose)
#     176
#     177       # Compute loss and gradients using the current minibatch
# --> 178       loss, grads = self.loss(X_batch, y=y_batch, reg=reg)
#     179       loss_history.append(loss)
#     180
#
# D:\Leon-Ma\000-Personal\cs231n\assignment1\cs231n\classifiers\neural_net.py in loss(self, X, y, reg)
#     123     dh_relu = (h_output > 0) *dh
#     124     grads['W1'] = X.T.dot(dh_relu) + reg * W1
# --> 125     grads['b1'] = np.sum(dh_relu, axis = 0)
#     126
#     127     #############################################################################
#
# D:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in sum(a, axis, dtype, out, keepdims)
#    1812             return sum(axis=axis, dtype=dtype, out=out, **kwargs)
#    1813     return _methods._sum(a, axis=axis, dtype=dtype,
# -> 1814                          out=out, **kwargs)
#    1815
#    1816
#
# D:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.103

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
