# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *
from sklearn.preprocessing import StandardScaler

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
# scaler = StandardScaler()
# X_train_feats_scaled = scaler.fit_transform(X_train_feats)
# X_val_feats_scaled = scaler.fit(X_val_feats)
# X_test_feats_scaled = scaler.fit(X_test_feats)

mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        svm = LinearSVM()
        svm.train(X_train_feats, y_train, learning_rate=lr, reg=reg, num_iters=2000, verbose=True)
        y_val_pred = svm.predict(X_val_feats)
        y_train_pred = svm.predict(X_train_feats)
        val_acc = np.mean(y_val == y_val_pred)
        train_acc = np.mean(y_train_pred == y_train)
        if best_val < val_acc:
            best_val = val_acc
            best_svm = svm
        results[(lr, reg)] = (train_acc, val_acc)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 2000: loss 47.881322 on train set
# iteration 100 / 2000: loss 47.494751 on train set
# iteration 200 / 2000: loss 47.107352 on train set
# iteration 300 / 2000: loss 46.722257 on train set
# iteration 400 / 2000: loss 46.352250 on train set
# iteration 500 / 2000: loss 45.981953 on train set
# iteration 600 / 2000: loss 45.611170 on train set
# iteration 700 / 2000: loss 45.243592 on train set
# iteration 800 / 2000: loss 44.897706 on train set
# iteration 900 / 2000: loss 44.542135 on train set
# iteration 1000 / 2000: loss 44.183530 on train set
# iteration 1100 / 2000: loss 43.850017 on train set
# iteration 1200 / 2000: loss 43.481841 on train set
# iteration 1300 / 2000: loss 43.142833 on train set
# iteration 1400 / 2000: loss 42.807004 on train set
# iteration 1500 / 2000: loss 42.475543 on train set
# iteration 1600 / 2000: loss 42.132792 on train set
# iteration 1700 / 2000: loss 41.811456 on train set
# iteration 1800 / 2000: loss 41.474309 on train set
# iteration 1900 / 2000: loss 41.164237 on train set
# iteration 0 / 2000: loss 403.458763 on train set
# iteration 100 / 2000: loss 365.898466 on train set
# iteration 200 / 2000: loss 331.926743 on train set
# iteration 300 / 2000: loss 301.197927 on train set
# iteration 400 / 2000: loss 273.389765 on train set
# iteration 500 / 2000: loss 248.219705 on train set
# iteration 600 / 2000: loss 225.457655 on train set
# iteration 700 / 2000: loss 204.846988 on train set
# iteration 800 / 2000: loss 186.207177 on train set
# iteration 900 / 2000: loss 169.336855 on train set
# iteration 1000 / 2000: loss 154.079822 on train set
# iteration 1100 / 2000: loss 140.267904 on train set
# iteration 1200 / 2000: loss 127.774060 on train set
# iteration 1300 / 2000: loss 116.458249 on train set
# iteration 1400 / 2000: loss 106.236550 on train set
# iteration 1500 / 2000: loss 96.976539 on train set
# iteration 1600 / 2000: loss 88.607041 on train set
# iteration 1700 / 2000: loss 81.030610 on train set
# iteration 1800 / 2000: loss 74.171904 on train set
# iteration 1900 / 2000: loss 67.966457 on train set
# iteration 0 / 2000: loss 3962.760070 on train set
# iteration 100 / 2000: loss 1459.861218 on train set
# iteration 200 / 2000: loss 541.407289 on train set
# iteration 300 / 2000: loss 204.373590 on train set
# iteration 400 / 2000: loss 80.690555 on train set
# iteration 500 / 2000: loss 35.308885 on train set
# iteration 600 / 2000: loss 18.654345 on train set
# iteration 700 / 2000: loss 12.543442 on train set
# iteration 800 / 2000: loss 10.299938 on train set
# iteration 900 / 2000: loss 9.476963 on train set
# iteration 1000 / 2000: loss 9.175029 on train set
# iteration 1100 / 2000: loss 9.064239 on train set
# iteration 1200 / 2000: loss 9.023587 on train set
# iteration 1300 / 2000: loss 9.008649 on train set
# iteration 1400 / 2000: loss 9.003171 on train set
# iteration 1500 / 2000: loss 9.001159 on train set
# iteration 1600 / 2000: loss 9.000418 on train set
# iteration 1700 / 2000: loss 9.000154 on train set
# iteration 1800 / 2000: loss 9.000049 on train set
# iteration 1900 / 2000: loss 9.000014 on train set
# iteration 0 / 2000: loss 45.787672 on train set
# iteration 100 / 2000: loss 42.309337 on train set
# iteration 200 / 2000: loss 39.113087 on train set
# iteration 300 / 2000: loss 36.267371 on train set
# iteration 400 / 2000: loss 33.662008 on train set
# iteration 500 / 2000: loss 31.312555 on train set
# iteration 600 / 2000: loss 29.190612 on train set
# iteration 700 / 2000: loss 27.274150 on train set
# iteration 800 / 2000: loss 25.522357 on train set
# iteration 900 / 2000: loss 23.951051 on train set
# iteration 1000 / 2000: loss 22.533623 on train set
# iteration 1100 / 2000: loss 21.250126 on train set
# iteration 1200 / 2000: loss 20.075534 on train set
# iteration 1300 / 2000: loss 19.029356 on train set
# iteration 1400 / 2000: loss 18.062032 on train set
# iteration 1500 / 2000: loss 17.202464 on train set
# iteration 1600 / 2000: loss 16.425542 on train set
# iteration 1700 / 2000: loss 15.711951 on train set
# iteration 1800 / 2000: loss 15.085984 on train set
# iteration 1900 / 2000: loss 14.499183 on train set
# iteration 0 / 2000: loss 417.499253 on train set
# iteration 100 / 2000: loss 158.897459 on train set
# iteration 200 / 2000: loss 64.006273 on train set
# iteration 300 / 2000: loss 29.183576 on train set
# iteration 400 / 2000: loss 16.406172 on train set
# iteration 500 / 2000: loss 11.718086 on train set
# iteration 600 / 2000: loss 9.997945 on train set
# iteration 700 / 2000: loss 9.365649 on train set
# iteration 800 / 2000: loss 9.134527 on train set
# iteration 900 / 2000: loss 9.049241 on train set
# iteration 1000 / 2000: loss 9.018076 on train set
# iteration 1100 / 2000: loss 9.006566 on train set
# iteration 1200 / 2000: loss 9.002328 on train set
# iteration 1300 / 2000: loss 9.000822 on train set
# iteration 1400 / 2000: loss 9.000261 on train set
# iteration 1500 / 2000: loss 9.000036 on train set
# iteration 1600 / 2000: loss 8.999979 on train set
# iteration 1700 / 2000: loss 8.999949 on train set
# iteration 1800 / 2000: loss 8.999912 on train set
# iteration 1900 / 2000: loss 8.999923 on train set
# iteration 0 / 2000: loss 3960.325353 on train set
# iteration 100 / 2000: loss 9.138475 on train set
# iteration 200 / 2000: loss 8.999999 on train set
# iteration 300 / 2000: loss 8.999993 on train set
# iteration 400 / 2000: loss 8.999992 on train set
# iteration 500 / 2000: loss 8.999992 on train set
# iteration 600 / 2000: loss 8.999995 on train set
# iteration 700 / 2000: loss 8.999994 on train set
# iteration 800 / 2000: loss 8.999992 on train set
# iteration 900 / 2000: loss 8.999992 on train set
# iteration 1000 / 2000: loss 8.999994 on train set
# iteration 1100 / 2000: loss 8.999995 on train set
# iteration 1200 / 2000: loss 8.999993 on train set
# iteration 1300 / 2000: loss 8.999994 on train set
# iteration 1400 / 2000: loss 8.999993 on train set
# iteration 1500 / 2000: loss 8.999994 on train set
# iteration 1600 / 2000: loss 8.999993 on train set
# iteration 1700 / 2000: loss 8.999994 on train set
# iteration 1800 / 2000: loss 8.999994 on train set
# iteration 1900 / 2000: loss 8.999993 on train set
# iteration 0 / 2000: loss 44.555546 on train set
# iteration 100 / 2000: loss 22.045096 on train set
# iteration 200 / 2000: loss 13.795110 on train set
# iteration 300 / 2000: loss 10.757502 on train set
# iteration 400 / 2000: loss 9.643832 on train set
# iteration 500 / 2000: loss 9.234739 on train set
# iteration 600 / 2000: loss 9.085684 on train set
# iteration 700 / 2000: loss 9.031363 on train set
# iteration 800 / 2000: loss 9.010629 on train set
# iteration 900 / 2000: loss 9.003255 on train set
# iteration 1000 / 2000: loss 9.001022 on train set
# iteration 1100 / 2000: loss 8.999885 on train set
# iteration 1200 / 2000: loss 8.999588 on train set
# iteration 1300 / 2000: loss 8.999363 on train set
# iteration 1400 / 2000: loss 8.999246 on train set
# iteration 1500 / 2000: loss 8.999414 on train set
# iteration 1600 / 2000: loss 8.999307 on train set
# iteration 1700 / 2000: loss 8.999514 on train set
# iteration 1800 / 2000: loss 8.999034 on train set
# iteration 1900 / 2000: loss 8.999447 on train set
# iteration 0 / 2000: loss 378.466724 on train set
# iteration 100 / 2000: loss 9.012989 on train set
# iteration 200 / 2000: loss 8.999929 on train set
# iteration 300 / 2000: loss 8.999938 on train set
# iteration 400 / 2000: loss 8.999922 on train set
# iteration 500 / 2000: loss 8.999933 on train set
# iteration 600 / 2000: loss 8.999927 on train set
# iteration 700 / 2000: loss 8.999928 on train set
# iteration 800 / 2000: loss 8.999923 on train set
# iteration 900 / 2000: loss 8.999919 on train set
# iteration 1000 / 2000: loss 8.999914 on train set
# iteration 1100 / 2000: loss 8.999922 on train set
# iteration 1200 / 2000: loss 8.999914 on train set
# iteration 1300 / 2000: loss 8.999938 on train set
# iteration 1400 / 2000: loss 8.999951 on train set
# iteration 1500 / 2000: loss 8.999923 on train set
# iteration 1600 / 2000: loss 8.999920 on train set
# iteration 1700 / 2000: loss 8.999936 on train set
# iteration 1800 / 2000: loss 8.999932 on train set
# iteration 1900 / 2000: loss 8.999940 on train set
# iteration 0 / 2000: loss 3653.069237 on train set
# iteration 100 / 2000: loss 8.999996 on train set
# iteration 200 / 2000: loss 8.999996 on train set
# iteration 300 / 2000: loss 8.999998 on train set
# iteration 400 / 2000: loss 8.999995 on train set
# iteration 500 / 2000: loss 8.999995 on train set
# iteration 600 / 2000: loss 8.999997 on train set
# iteration 700 / 2000: loss 8.999995 on train set
# iteration 800 / 2000: loss 8.999995 on train set
# iteration 900 / 2000: loss 8.999997 on train set
# iteration 1000 / 2000: loss 8.999996 on train set
# iteration 1100 / 2000: loss 8.999996 on train set
# iteration 1200 / 2000: loss 8.999995 on train set
# iteration 1300 / 2000: loss 8.999996 on train set
# iteration 1400 / 2000: loss 8.999996 on train set
# iteration 1500 / 2000: loss 8.999997 on train set
# iteration 1600 / 2000: loss 8.999995 on train set
# iteration 1700 / 2000: loss 8.999995 on train set
# iteration 1800 / 2000: loss 8.999997 on train set
# iteration 1900 / 2000: loss 8.999995 on train set
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.099755 val accuracy: 0.100000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.097959 val accuracy: 0.109000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.373306 val accuracy: 0.396000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.109898 val accuracy: 0.097000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.412041 val accuracy: 0.407000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.408082 val accuracy: 0.406000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.413571 val accuracy: 0.412000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.407041 val accuracy: 0.412000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.373184 val accuracy: 0.357000
# best validation accuracy achieved during cross-validation: 0.412000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.425

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print(X_train_feats.shape)
# Out:
# (49000, 155)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None
################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
learning_rates = [0.31, 0.32, 0.33, 0.34, 0.35]
learning_rate_decays = [0.999]
regs = [5e-3, 4e-3, 6e-3]
best_val = -1
result = {'best_params':None}
num_i = 0
num_total = len(learning_rates)*len(learning_rate_decays)*len(regs)
for lr in learning_rates:
    for lrd in learning_rate_decays:
        for reg in regs:
            stats = net.train(X_train_feats, y_train, X_val_feats, y_val, lr, lrd, reg, 
                      num_iters=2000)
            y_train_pred = net.predict(X_train_feats)
            y_val_pred = net.predict(X_val_feats)
            train_acc = np.mean(y_train == y_train_pred)
            val_acc = np.mean(y_val == y_val_pred)
            if best_val < val_acc:
                best_val = val_acc
                best_net = net
                result['best_params'] = (lr, lrd, reg)
            num_i += 1
            print('lr %3f, lrd %.3f, reg %.3f '%(lr, lrd, reg))
            print('iteration %d / %d, train acc %.3f, vald acc %.3f'%(num_i, num_total, train_acc, val_acc))

            
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# lr 0.310000, lrd 0.999, reg 0.005
# iteration 1 / 15, train acc 0.618, vald acc 0.563
# lr 0.310000, lrd 0.999, reg 0.004
# iteration 2 / 15, train acc 0.662, vald acc 0.590
# lr 0.310000, lrd 0.999, reg 0.006
# iteration 3 / 15, train acc 0.627, vald acc 0.568
# lr 0.320000, lrd 0.999, reg 0.005
# iteration 4 / 15, train acc 0.651, vald acc 0.581
# lr 0.320000, lrd 0.999, reg 0.004
# iteration 5 / 15, train acc 0.674, vald acc 0.593
# lr 0.320000, lrd 0.999, reg 0.006
# iteration 6 / 15, train acc 0.643, vald acc 0.589
# lr 0.330000, lrd 0.999, reg 0.005
# iteration 7 / 15, train acc 0.656, vald acc 0.571
# lr 0.330000, lrd 0.999, reg 0.004
# iteration 8 / 15, train acc 0.673, vald acc 0.565
# lr 0.330000, lrd 0.999, reg 0.006
# iteration 9 / 15, train acc 0.643, vald acc 0.607
# lr 0.340000, lrd 0.999, reg 0.005
# iteration 10 / 15, train acc 0.651, vald acc 0.596
# lr 0.340000, lrd 0.999, reg 0.004
# iteration 11 / 15, train acc 0.683, vald acc 0.595
# lr 0.340000, lrd 0.999, reg 0.006
# iteration 12 / 15, train acc 0.642, vald acc 0.586
# lr 0.350000, lrd 0.999, reg 0.005
# iteration 13 / 15, train acc 0.649, vald acc 0.580
# lr 0.350000, lrd 0.999, reg 0.004
# iteration 14 / 15, train acc 0.675, vald acc 0.588
# lr 0.350000, lrd 0.999, reg 0.006
# iteration 15 / 15, train acc 0.643, vald acc 0.583

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.563

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
